# %% [markdown]
# # Atividades de Python: Teste seus conhecimentos

# %% [markdown]
# 1. Crie a classe Televisao com os atributos ligada (inicializado com valor False) e canal (inicializado com valor  2).

# %%
class Televisao:
    def __init__(self):
        self.ligada = False
        self.canal = 2

# %% [markdown]
# 2. Adicione os atributos tamanho e marca à classe Televisao. Crie dois objetos Televisao e atribua tamanhos e marcas diferentes. Depois, imprima o valor desses atributos de forma a confirmar independência dos valores de cada instância (objeto).

# %%
tv = Televisao()
tv.tamanho = 42
tv.marca = "Televisao1"
tv_sala = Televisao()
tv_sala.tamanho = 70
tv_sala.marca = "Televisao2"

print(f"tv tamanho={tv.tamanho} marca={tv.marca}")
print(f"tv_sala tamanho={tv_sala.tamanho} marca={tv_sala.marca}")
# Out:
# tv tamanho=42 marca=Televisao1
# tv_sala tamanho=70 marca=Televisao2

# %% [markdown]
# 3. Adicione dois novos métodos muda_canal_para_cima e muda_canal_para_baixo. Atualmente, a classe Televisao inicializa o canal com 2. Modifique a classe televisao de forma a receber o canal inicial em seu construtor.

# %%
class Televisao:
    def __init__(self, canal_inicial, min, max):
        self.ligada = False
        self.canal = canal_inicial
        self.cmin = min
        self.cmax = max

    def muda_canal_para_baixo(self):
        if self.canal-1 >= self.cmin:
            self.canal -= 1

    def muda_canal_para_cima(self):
        if self.canal+1 <= self.cmax:
            self.canal += 1


tv = Televisao(5, 1, 99)

print(tv.canal)
# Out:
# 5

# %% [markdown]
# 4. Adicione mais dois atributos canal_minimo (valor padrão 1) e canal_maximo (valor padrão 99) e modifique a classe Televisao de forma que, se pedirmos para mudar o canal para baixo, além do mínimo, ela vá para o canal máximo. Se mudarmos para cima, além do canal máximo, que volte ao canal mínimo.

# %%
class Televisao:
    def __init__(self, min, max):
        self.ligada = False
        self.canal = min
        self.cmin = min
        self.cmax = max

    def muda_canal_para_baixo(self):
        if self.canal-1 >= self.cmin:
            self.canal -= 1
        else:
            self.canal = self.cmax

    def muda_canal_para_cima(self):
        if self.canal+1 <= self.cmax:
            self.canal += 1
        else:
            self.canal = self.cmin


tv = Televisao(1, 99)
tv.muda_canal_para_baixo()
print(tv.canal)
tv.muda_canal_para_cima()
print(tv.canal)
# Out:
# 99
# 1

# %% [markdown]
# 5. Modifique o construtor da classe Televisao de forma que canal_minimo e canal_maximo seja parametros opcionais valendo respectivamente 2 e 14.

# %%
class Televisão:
    def __init__(self, min=2, max=14):
        self.ligada = False
        self.canal = min
        self.cmin = min
        self.cmax = max

    def muda_canal_para_baixo(self):
        if self.canal-1 >= self.cmin:
            self.canal -= 1
        else:
            self.canal = self.cmax

    def muda_canal_para_cima(self):
        if self.canal+1 <= self.cmax:
            self.canal += 1
        else:
            self.canal = self.cmin


tv = Televisão()
tv.muda_canal_para_baixo()
print(tv.canal)
tv.muda_canal_para_cima()
print(tv.canal)
# Out:
# 14
# 2

# %% [markdown]
# 6. Crie as classes necessárias para um sistema de gerenciamento de uma biblioteca. Os bibliotecários deverão preencher o sistema com o título do livro, os autores, o ano, a editora, a edição e o volume. A biblioteca também terá um sistema de pesquisa (outro software), portanto será necessário conseguir acessar os atributos típicos de pesquisa (nome, autor, …).

# %%
class Biblioteca:
    def __init__(self):
        self.livros = []

    def add_livro(self, livro):
        self.livros.append(livro)

    def get_livros(self):
        return self.livros

    def mostra_livros(self):
        for livro in self.livros:
            print(str(livro))
    def busca_livros(self, titulo):
        for p in self.livros:
            if p.titulo == titulo:
                print('Livro encontrado:', p)
                return
        print('Nenhuma instância encontrada para: '+titulo)  

class Livro:
    def __init__(self, titulo, autores, ano, editora, edicao, volume):
        self.titulo = titulo
        self.autores = autores
        self.ano = ano
        self.editora = editora
        self.edicao = edicao
        self.volume = volume
    
    def __str__(self):
        return f"{self.titulo}, {self.autores}, {self.ano}, {self.editora}, {self.edicao}, {self.volume}"


lib = Biblioteca()
livro1 = Livro("O grande cantor", "John Smith", 2017, "Editora XYZ", "2º edição", "volume 2")
lib.add_livro(Livro("Codigo limpo", ["Ana Silva", "joão merl"], 2011, "Editora tal", "5º edição", 8))
livro2 = Livro("Final", "Pedro Pedroso", 1997, "Livros e etc", 4, 7)

lib.add_livro(livro1)
lib.add_livro(livro2)
lib.mostra_livros()
todos_os_livros = lib.get_livros()
outra_forma_de_todos_os_livros = lib.livros

lib.busca_livros("Final")
lib.busca_livros("A outra")
# Out:
# Codigo limpo, ['Ana Silva', 'joão merl'], 2011, Editora tal, 5º edição, 8
# O grande cantor, John Smith, 2017, Editora XYZ, 2º edição, volume 2
# Final, Pedro Pedroso, 1997, Livros e etc, 4, 7
# Livro encontrado: Final, Pedro Pedroso, 1997, Livros e etc, 4, 7
# Nenhuma instância encontrada para: A outra

# %% [markdown]
# 7. Faça um programa que leia um número indeterminado de valores, correspondentes a notas, encerrando a entrada de dados quando for informado um valor igual a -1 (que não deve ser armazenado). Após esta entrada de dados, faça:
#
#   a) Mostre a quantidade de valores que foram lidos;
# Exiba todos os valores na ordem em que foram informados, um ao lado do outro;
#
#   b) Exiba todos os valores na ordem inversa à que foram informados, um abaixo do outro;
#
#   c) Calcule e mostre a soma dos valores;
#
#   d) Calcule e mostre a média dos valores;
#
#   e) Calcule e mostre a quantidade de valores acima da média calculada;
#
#   f) Calcule e mostre a quantidade de valores abaixo de sete;
#
#   g) Encerre o programa com uma mensagem;

# %%
#Faça um programa que leia um número indeterminado de valores, correspondentes a notas, encerrando a entrada de dados quando for informado um valor igual a -1 (que não deve ser armazenado). Após esta entrada de dados, faça:

def leitura_dados():
  num = 0
  arr = list()
  print("~~ PROGRAMA INICIADO ~~")
  while num != -1:
    num = int(input("digite um valor: "))
    if(num != -1):
      arr.append(num)
  print("~~ FIM DA LEITURA ~~")
  return arr

arr = leitura_dados()

#a) Mostre a quantidade de valores que foram lidos; Exiba todos os valores na ordem em que foram informados, um ao lado do outro;
print("Foram lidos "+str(len(arr))+" números:", arr)
#b) Exiba todos os valores na ordem inversa à que foram informados, um abaixo do outro;
print("Lista invertida: ", arr[::-1])
#c) Calcule e mostre a soma dos valores;
print("Soma dos ítens da lista: ", sum(arr))
#d) Calcule e mostre a média dos valores;
print("Média dos ítens da lista: ", sum(arr)/len(arr))
#e) Calcule e mostre a quantidade de valores acima da média calculada;
maiores = []
menores = []
for i in arr:
  if i>sum(arr)/len(arr):
    maiores.append(i)
  elif i<sum(arr)/len(arr):
    menores.append(i)

print("Há "+str(len(maiores))+" valores acima da média: ", maiores)
#f) Calcule e mostre a quantidade de valores abaixo de sete;
print("Há "+str(len(menores))+" valores abaixo da média: ", menores)
#g) Encerre o programa com uma mensagem;
print("~~ PROGRAMA ENCERRADO ~~")
# Out:
# ~~ PROGRAMA INICIADO ~~
# digite um valor: 8
# digite um valor: 3
# digite um valor: 0
# digite um valor: 2
# digite um valor: 5
# digite um valor: 3
# digite um valor: -1
# ~~ FIM DA LEITURA ~~
# Foram lidos 6 números: [8, 3, 0, 2, 5, 3]
# Lista invertida:  [3, 5, 2, 0, 3, 8]
# Soma dos ítens da lista:  21
# Média dos ítens da lista:  3.5
# Há 2 valores acima da média:  [8, 5]
# Há 4 valores abaixo da média:  [3, 0, 2, 3]
# ~~ PROGRAMA ENCERRADO ~~

# %% [markdown]
# 8. Faça um Programa que leia dois vetores com 10 elementos cada. Gere um terceiro vetor de 20 elementos, cujos valores deverão ser compostos pelos elementos intercalados dos dois outros vetores.

# %%
vec1 = list()
vec2 = list()
vec3 = list()

print('Primeiro Vetor')

for i in range(10):
 vec1.append(int(input(f'Digite o valor do {i+1}° elemento: ')))

print('\nSegundo Vetor')
for i in range(10):
 vec2.append(int(input(f'Digite o valor do {i+1}° elemento: ')))

for i in range(10):
 vec3.append(vec1[i])
 vec3.append(vec2[i])

print(f'\nO terceiro vetor fica: {vec3}')
# Out:
# Primeiro Vetor
# Digite o valor do 1° elemento: 7
# Digite o valor do 2° elemento: 3
# Digite o valor do 3° elemento: 1
# Digite o valor do 4° elemento: -1
# Digite o valor do 5° elemento: 3
# Digite o valor do 6° elemento: 4
# Digite o valor do 7° elemento: 5
# Digite o valor do 8° elemento: 6
# Digite o valor do 9° elemento: 7
# Digite o valor do 10° elemento: 8
#
# Segundo Vetor
# Digite o valor do 1° elemento: 9
# Digite o valor do 2° elemento: 3
# Digite o valor do 3° elemento: 1
# Digite o valor do 4° elemento: 4
# Digite o valor do 5° elemento: 5
# Digite o valor do 6° elemento: 9
# Digite o valor do 7° elemento: 0
# Digite o valor do 8° elemento: 05
# Digite o valor do 9° elemento: 5
# Digite o valor do 10° elemento: 0
#
# O terceiro vetor fica: [7, 9, 3, 3, 1, 1, -1, 4, 3, 5, 4, 9, 5, 0, 6, 5, 7, 5, 8, 0]

# %% [markdown]
# 9. Escreva um programa que lê duas notas de vários alunos e armazena tais notas em um dicionário, onde a chave é o nome do aluno. A entrada de dados deve terminar quando for lida uma string vazia como nome. Escreva uma função que retorna a média do aluno, dado seu nome.

# %%
def cadastroAlunos():
  alunos = {}
  nome = 'oi'
  while nome != '':
    nome = str (input ("Digite o nome do aluno: "))
    if nome == '':
      return alunos
    b = int (input ("Digite a primeira nota: "))
    c = int (input ("Digite a segunda nota: "))
    media = (b + c) / 2
    alunos[nome] = media
    print(alunos)
  return alunos

def buscaAluno(alunos, nome):
  for key in alunos:
    if nome == key:
      print(f'Aluno {key} encontrado, média: {alunos[key]}')
      return
  print("Aluno não encontrado")


alunos = cadastroAlunos()

nome = input("Buscar aluno\nDigite o nome do aluno: ")
buscaAluno(alunos, nome)
# Out:
# Digite o nome do aluno: jessica
# Digite a primeira nota: 3
# Digite a segunda nota: 9
# {'jessica': 6.0}
# Digite o nome do aluno: 0
# Digite a primeira nota: 9
# Digite a segunda nota: 9
# {'jessica': 6.0, '0': 9.0}
# Digite o nome do aluno: beto
# Digite a primeira nota: 4
# Digite a segunda nota: 5
# {'jessica': 6.0, '0': 9.0, 'beto': 4.5}
# Digite o nome do aluno:
# Buscar aluno
# Digite o nome do aluno: jessica
# Aluno jessica encontrado, média: 6.0

# %% [markdown]
# 10. Escreva um programa para armazenar uma agenda de telefones usando um dicionário. Cada pessoa pode ter um ou mais telefones e a chave do dicionário é o nome completo da pessoa. Seu programa deve ter as seguintes funções:
#
# ­a) incluir_novo_nome – essa função acrescenta um novo nome na agenda, com um ou mais telefones. Ela deve receber como argumentos o nome e os telefones.
#
# b) incluir_telefone – essa função acrescenta um telefone em um nome existente na agenda. Caso o nome não exista na agenda, você deve perguntar se a pessoa deseja incluí-­lo. Caso a resposta seja afirmativa, use a função anterior para incluir o novo nome.
#  ­
# c) excluir_telefone – essa função exclui um telefone de uma pessoa que
# já está na agenda. Se a pessoa tiver apenas um telefone, ela deve ser excluída da agenda.
#
# d) excluir_nome – essa função exclui uma pessoa da agenda.
#
# e) consultar_telefone – essa função retorna os telefones de uma pessoa
# na agenda.

# %%
def incluir_novo_nome(agenda, nome, telefone):
  agenda[nome] = telefone
def incluir_telefone(agenda, nome, telefone):
  agenda[nome].append(telefone)
def excluir_telefone(agenda, nome, telefone):
  if (len(agenda[nome])==1):
    del agenda[nome]
  else:
    agenda[nome].remove(telefone)
def excluir_nome(agenda, nome):
  del agenda[nome]
def consultar_telefone(agenda, nome):
  print(agenda[nome])

def mostra_contatos(agenda):
  for keys in agenda:
    print(f'Nome: {keys} \nTelefones: {agenda[keys]}')

# Utilizando a agenda
agenda = dict()
print("Incluindo nomes na agenda")
incluir_novo_nome(agenda, 'Suzana Vieira', ["(21) 99080-7218", "(21) 3322-0911"])
incluir_novo_nome(agenda, 'Angelica Roftman', ["(21) 97787-0115"])
incluir_novo_nome(agenda, 'Jorge Felix', ["(21) 98167-3813"])
incluir_novo_nome(agenda, 'Eric Amorim', ["(62) 99078-8827"])

mostra_contatos(agenda)

print("\nAdicionando um numero a um contato existente")
incluir_telefone(agenda, 'Eric Amorim', ["(62) 99078-8827"])
mostra_contatos(agenda)

print("\nConsultando um contato:")
consultar_telefone(agenda, "Jorge Felix")

print("\nExcluindo um numero:")
excluir_telefone(agenda, 'Suzana Vieira', "(21) 99080-7218")
mostra_contatos(agenda)

print("\nExcluindo um contato:")
excluir_nome(agenda, 'Angelica Roftman')
# Out:
# Incluindo nomes na agenda
# Nome: Suzana Vieira
# Telefones: ['(21) 99080-7218', '(21) 3322-0911']
# Nome: Angelica Roftman
# Telefones: ['(21) 97787-0115']
# Nome: Jorge Felix
# Telefones: ['(21) 98167-3813']
# Nome: Eric Amorim
# Telefones: ['(62) 99078-8827']
#
# Adicionando um numero a um contato existente
# Nome: Suzana Vieira
# Telefones: ['(21) 99080-7218', '(21) 3322-0911']
# Nome: Angelica Roftman
# Telefones: ['(21) 97787-0115']
# Nome: Jorge Felix
# Telefones: ['(21) 98167-3813']
# Nome: Eric Amorim
# Telefones: ['(62) 99078-8827', ['(62) 99078-8827']]
#
# Consultando um contato:
# ['(21) 98167-3813']
# \Excluindo um contato:
# Nome: Suzana Vieira
# Telefones: ['(21) 3322-0911']
# Nome: Angelica Roftman
# Telefones: ['(21) 97787-0115']
# Nome: Jorge Felix
# Telefones: ['(21) 98167-3813']
# Nome: Eric Amorim
# Telefones: ['(62) 99078-8827', ['(62) 99078-8827']]
